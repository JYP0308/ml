# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
house = pd.read_csv("data/housing/housing.csv")

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
house.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
house.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
house.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
# 创建测试集
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data)*test_ratio)
    test_indices=shuffled_indices[:test_set_size]
    train_indices=shuffled_indices[test_set_size:]
    return data.iloc[test_indices], data.iloc[train_indices]

# %%
def test_set_check(identifier, test_ratio, hash):
    return hash(np.int64(identifier)).digest()[-1]<256*test_ratio

def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):
    ids = data[id_column]
    in_test_set=ids.apply(lambda _id: test_set_check(_id, test_ratio, hash))
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
house_with_idx = house.reset_index()

# %%
test_set, train_set = split_train_test_by_id(house_with_idx, 0.2, "index")
train_set
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 4          4    -122.25     37.85                52.0       1627.0
# 5          5    -122.25     37.85                52.0        919.0
# 11        11    -122.26     37.85                52.0       3503.0
# 20        20    -122.27     37.85                40.0        751.0
# 23        23    -122.27     37.84                52.0       1688.0
# ...      ...        ...       ...                 ...          ...
# 20619  20619    -121.56     39.01                22.0       1891.0
# 20625  20625    -121.52     39.12                37.0        102.0
# 20632  20632    -121.45     39.26                15.0       2319.0
# 20633  20633    -121.53     39.19                27.0       2080.0
# 20637  20637    -121.22     39.43                17.0       2254.0
#
#        total_bedrooms  population  households  median_income  \
# 4               280.0       565.0       259.0         3.8462
# 5               213.0       413.0       193.0         4.0368
# 11              752.0      1504.0       734.0         3.2705
# 20              184.0       409.0       166.0         1.3578
# 23              337.0       853.0       325.0         2.1806
# ...               ...         ...         ...            ...
# 20619           340.0      1023.0       296.0         2.7303
# 20625            17.0        29.0        14.0         4.1250
# 20632           416.0      1047.0       385.0         3.1250
# 20633           412.0      1082.0       382.0         2.5495
# 20637           485.0      1007.0       433.0         1.7000
#
#        median_house_value ocean_proximity
# 4                342200.0        NEAR BAY
# 5                269700.0        NEAR BAY
# 11               241800.0        NEAR BAY
# 20               147500.0        NEAR BAY
# 23                99700.0        NEAR BAY
# ...                   ...             ...
# 20619             99100.0          INLAND
# 20625             72000.0          INLAND
# 20632            115600.0          INLAND
# 20633             98300.0          INLAND
# 20637             92300.0          INLAND
#
# [4278 rows x 11 columns]

# %%
house["income_cut"] = np.ceil(house["median_income"]/1.5)
house["income_cut"].where(house.income_cut<5, 5.0, inplace=True)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
# 分层抽样
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=41)

# %%
for train_index, test_index in split.split(house, house.income_cut):
    strat_train_set = house.loc[train_index]
    strat_test_set = house.loc[test_index]

# %%
strat_test_set.income_cut.value_counts()/len(strat_test_set)
# Out:
# 3.0    0.350533
# 2.0    0.318798
# 4.0    0.176357
# 5.0    0.114583
# 1.0    0.039729
# Name: income_cut, dtype: float64

# %%
strat_train_set.income_cut.value_counts()/len(strat_train_set)
# Out:
# 3.0    0.350594
# 2.0    0.318859
# 4.0    0.176296
# 5.0    0.114402
# 1.0    0.039850
# Name: income_cut, dtype: float64

# %%
strat_test_set.drop("income_cut", axis=1, inplace=True)
strat_train_set.drop("income_cut", axis=1, inplace=True)

# %%
strat_train_set.to_csv("./temp_data/housing.csv", index=False)

# %%
housing = pd.read_csv("./temp_data/housing.csv")

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -118.03     33.82                20.0       2662.0           464.0
# 1        -117.85     33.62                13.0       5192.0           658.0
# 2        -121.51     38.57                36.0        613.0           166.0
# 3        -123.63     41.11                19.0       1797.0           384.0
# 4        -117.60     33.87                18.0       6450.0          1165.0
# ...          ...       ...                 ...          ...             ...
# 16507    -117.91     33.76                22.0       7531.0          1569.0
# 16508    -121.97     37.31                25.0       5775.0          1225.0
# 16509    -122.52     37.90                16.0       1704.0           402.0
# 16510    -121.86     37.38                15.0       2052.0           405.0
# 16511    -118.06     34.10                38.0       2438.0           442.0
#
#        population  households  median_income  median_house_value  \
# 0          1275.0       472.0         6.0162            318500.0
# 1          1865.0       662.0        15.0001            500001.0
# 2           425.0       147.0         2.2031             93800.0
# 3          1033.0       327.0         1.4911             59200.0
# 4          3716.0      1113.0         4.2721            150300.0
# ...           ...         ...            ...                 ...
# 16507      5254.0      1523.0         3.8506            167400.0
# 16508      3580.0      1138.0         3.9187            314900.0
# 16509       689.0       348.0         4.4239            267100.0
# 16510      1380.0       409.0         5.8686            181100.0
# 16511      1308.0       461.0         3.6995            260100.0
#
#       ocean_proximity
# 0           <1H OCEAN
# 1           <1H OCEAN
# 2              INLAND
# 3           <1H OCEAN
# 4              INLAND
# ...               ...
# 16507       <1H OCEAN
# 16508       <1H OCEAN
# 16509        NEAR BAY
# 16510       <1H OCEAN
# 16511       <1H OCEAN
#
# [16512 rows x 10 columns]

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.49)
plt.show()

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.5,
            s=housing["population"]/100, label="population",
            c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True)
plt.show()

# %%
housing.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924208           -0.109516     0.049306
# latitude            -0.924208  1.000000            0.011499    -0.038834
# housing_median_age  -0.109516  0.011499            1.000000    -0.363013
# total_rooms          0.049306 -0.038834           -0.363013     1.000000
# total_bedrooms       0.074237 -0.068830           -0.323297     0.931339
# population           0.105816 -0.112147           -0.300212     0.857320
# households           0.059781 -0.072910           -0.305806     0.918272
# median_income       -0.019568 -0.076904           -0.114760     0.196804
# median_house_value  -0.049897 -0.141620            0.111686     0.131987
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.074237    0.105816    0.059781      -0.019568
# latitude                 -0.068830   -0.112147   -0.072910      -0.076904
# housing_median_age       -0.323297   -0.300212   -0.305806      -0.114760
# total_rooms               0.931339    0.857320    0.918272       0.196804
# total_bedrooms            1.000000    0.877830    0.978793      -0.007924
# population                0.877830    1.000000    0.908247       0.004892
# households                0.978793    0.908247    1.000000       0.012923
# median_income            -0.007924    0.004892    0.012923       1.000000
# median_house_value        0.046671   -0.024677    0.063285       0.687668
#
#                     median_house_value
# longitude                    -0.049897
# latitude                     -0.141620
# housing_median_age            0.111686
# total_rooms                   0.131987
# total_bedrooms                0.046671
# population                   -0.024677
# households                    0.063285
# median_income                 0.687668
# median_house_value            1.000000
